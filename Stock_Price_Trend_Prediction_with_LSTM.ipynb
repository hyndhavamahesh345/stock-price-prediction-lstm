# %% [markdown]
# <a href="https://colab.research.google.com/github/hyndhavamahesh345/stock-price-prediction-lstm/blob/main/Stock_Price_Trend_Prediction_with_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# stock_predictor

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import os

# Configuration
# Define the stock ticker symbol
TICKER = "MSFT" # Example: Microsoft
# Define the start and end dates for fetching data
START_DATE = "2010-01-01"
END_DATE = "2023-12-31"
# Define the look-back period for LSTM (how many past days to consider for prediction)
LOOK_BACK = 60 # Using 60 past days to predict the next day's price
# Define the train-test split ratio
TRAIN_RATIO = 0.8
# Define batch size and epochs for training
BATCH_SIZE = 64
EPOCHS = 20

# Fetch Data using yfinance API
print(f"Fetching historical data for {TICKER} from {START_DATE} to {END_DATE}...")
try:
    df = yf.download(TICKER, start=START_DATE, end=END_DATE)
    if df.empty:
        raise ValueError("No data fetched. Check ticker and date range.")
    print("Data fetched successfully.")
    print(df.head())
    print(df.tail())
except Exception as e:
    print(f"Error fetching data: {e}")
    exit()

# Use only the 'Close' price for prediction
data = df['Close'].values.reshape(-1, 1)

# Normalize and Prepare Data
print("Normalizing data and preparing sequences...")
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Split data into training and testing sets
train_size = int(len(scaled_data) * TRAIN_RATIO)
train_data = scaled_data[0:train_size, :]
test_data = scaled_data[train_size - LOOK_BACK:, :] # Include look_back period for test data

# Function to create sequences for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

X_train, y_train = create_dataset(train_data, LOOK_BACK)
X_test, y_test = create_dataset(test_data, LOOK_BACK)

# Reshape input to be [samples, time steps, features] for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print("Data preparation complete.")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Build LSTM Model using Keras
print("Building LSTM model...")
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(LOOK_BACK, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1)) # Output layer for predicting the next price

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
print("Model built.")

# Train and Validate Model
print("Training LSTM model...")
history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=1)
print("Model training complete.")

# Save model weights (optional)
# Corrected the filename to end with .weights.h5 as required by Keras
model_weights_path = f"{TICKER}_lstm_model.weights.h5"
model.save_weights(model_weights_path)
print(f"Model weights saved to {model_weights_path}")

# Plot predictions vs actual
print("Making predictions and plotting results...")
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions and actual values to original scale
train_predict = scaler.inverse_transform(train_predict)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create plots directory if it doesn't exist
plots_dir = "plots"
os.makedirs(plots_dir, exist_ok=True)

# Plot training predictions
plt.figure(figsize=(16, 8))
plt.plot(y_train_actual, label='Actual Price (Training)')
plt.plot(train_predict, label='Predicted Price (Training)')
plt.title(f'{TICKER} Stock Price Prediction - Training Data')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plots_dir, f'{TICKER}_training_prediction.png'))
plt.show()

# Plot testing predictions
plt.figure(figsize=(16, 8))
# Create an array to hold predictions, filling with NaN where no prediction exists for alignment
full_data_plot = df['Close'].values.reshape(-1, 1)
train_predict_plot = np.empty_like(full_data_plot)
train_predict_plot[:, :] = np.nan
train_predict_plot[LOOK_BACK:len(train_predict)+LOOK_BACK, :] = train_predict

test_predict_plot = np.empty_like(full_data_plot)
test_predict_plot[:, :] = np.nan

test_predict_plot[train_size:len(full_data_plot), :] = test_predict

plt.plot(scaler.inverse_transform(scaled_data), label='Actual Stock Price')
plt.plot(train_predict_plot, label='Training Prediction')
plt.plot(test_predict_plot, label='Testing Prediction')
plt.title(f'{TICKER} Stock Price Prediction - Overall')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plots_dir, f'{TICKER}_overall_prediction.png'))
plt.show()

# Integrate Moving Average & RSI indicators
print("Calculating and plotting Moving Average and RSI indicators...")

# Calculate Simple Moving Average (SMA)
df['SMA_20'] = df['Close'].rolling(window=20).mean()
df['SMA_50'] = df['Close'].rolling(window=50).mean()

# Calculate Relative Strength Index (RSI)
def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

df['RSI'] = calculate_rsi(df['Close'])

# Plot with indicators
plt.figure(figsize=(16, 10))

# Subplot 1: Close Price with Moving Averages
plt.subplot(2, 1, 1)
plt.plot(df['Close'], label='Close Price', color='blue')
plt.plot(df['SMA_20'], label='20-Day SMA', color='orange')
plt.plot(df['SMA_50'], label='50-Day SMA', color='green')
plt.title(f'{TICKER} Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Subplot 2: RSI
plt.subplot(2, 1, 2)
plt.plot(df['RSI'], label='RSI', color='purple')
plt.axhline(70, linestyle='--', alpha=0.5, color='red', label='Overbought (70)')
plt.axhline(30, linestyle='--', alpha=0.5, color='green', label='Oversold (30)')
plt.title(f'{TICKER} Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI Value')
plt.ylim(0, 100)
plt.legend()
plt.grid(True)

plt.tight_layout() # Adjust layout to prevent overlapping
plt.savefig(os.path.join(plots_dir, f'{TICKER}_indicators_plot.png'))
plt.show()

print("Script execution complete. Check 'plots' directory for generated graphs.")
# Out:
# /tmp/ipython-input-4-2576569446.py:29: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(TICKER, start=START_DATE, end=END_DATE)
# [*********************100%***********************]  1 of 1 completed
# Fetching historical data for MSFT from 2010-01-01 to 2023-12-31...
# Data fetched successfully.
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2010-01-04  23.211437  23.323932  22.941449  22.963949  38409100
# 2010-01-05  23.218939  23.323935  22.978950  23.136444  49749600
# 2010-01-06  23.076447  23.308936  22.888955  23.158942  58182400
# 2010-01-07  22.836462  23.023953  22.641471  22.971455  50559700
# 2010-01-08  22.993942  23.158934  22.678957  22.708956  51197400
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# ...
